# %% [markdown]
# # 0.1 First data view

# %%
# %matplotlib inline

# %%
cd /Users/anacriel/plant_seed_classification/src/
# Out:
# /Users/anacriel/plant_seed_classification/src

# %%
import src.visualization.visualize as vs
import os

# %% [markdown]
# #### Set working directories

# %%
proc_data_dir = '../data/processed/'
train_image_dir = os.path.join(proc_data_dir, 'train')

# %% [markdown]
# #### Reading images using cv2 library

# %%
images_per_class = vs.read_images(train_image_dir, data_type='train')
# Out:
# 4750

# %% [markdown]
# #### Print classes names and numbers of images per class

# %%
for key, value in images_per_class.items():
    print("{} - {}".format(key, len(value)) + ' images')
# Out:
# Cleavers - 287 images
# Sugar beet - 385 images
# Common Chickweed - 611 images
# Loose Silky-bent - 654 images
# Scentless Mayweed - 516 images
# Shepherds Purse - 231 images
# Fat Hen - 475 images
# Common wheat - 221 images
# Black-grass - 263 images
# Small-flowered Cranesbill - 496 images
# Charlock - 390 images
# Maize - 221 images

# %% [markdown]
# #### Show the dataset examples in grid layout

# %%
vs.plot_raw_grid(images_per_class)

# %% [markdown]
# #### Separate the images from the background

# %%
images_segmented = vs.segment_plant(images_per_class)

# %% [markdown]
# #### Show the images with no background in grid layout

# %%
vs.plot_raw_grid(images_segmented)
